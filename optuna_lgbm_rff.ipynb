# %% [markdown]
# # Solution
#
# - We concatenated data for the same Ids.
# - We added 30 Random Fourier Features to our data.
# - Then we run LightGBM. We useed optuna for hyperparameter tuning.

# %%
import pandas as pd
import numpy as np

import optuna
from lightgbm import LGBMClassifier

from sklearn.model_selection import StratifiedKFold
from optuna.integration import LightGBMPruningCallback
from sklearn.metrics import roc_auc_score

from functools import reduce
from sklearn.kernel_approximation import RBFSampler

# %%
def data_pipe(data):
    weeks = []

    for week in data.Week.unique():
        weeks.append(data[data.Week == week]\
                     .add_prefix(f'w{week}_')\
                     .rename(columns={f'w{week}_Id': 'Id'}))

    merge = lambda l,r : l.merge(r, on='Id', how='left')
    return reduce(merge, weeks)

# %%
#df = data_pipe(pd.read_csv('train.csv')).drop(columns='Id')

sub = data_pipe(pd.read_csv('test.csv'))
sub_id = sub.Id
sub = sub.drop(columns='Id')

# %%
df = data_pipe(pd.read_csv('train.csv')).drop(columns='Id')
train_x = df.drop(columns=['w0_target', 'w1_target', 'w2_target', 'w3_target'])
train_y = df.w0_target

# %%
sampler = RBFSampler(n_components=30)
sampler.fit(train_x.fillna(0), train_y)
rff_train = pd.DataFrame(sampler.transform(train_x.fillna(0)))
sub_rff = pd.DataFrame(sampler.transform(sub.fillna(0)))

# %%
y = df.w0_target
X = df.drop(columns=['w0_target', 'w1_target', 'w2_target', 'w3_target'])
X = pd.DataFrame(np.hstack([X.values, rff_train]))
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
sub = pd.DataFrame(np.hstack([sub.values, sub_rff]))

# %%
def objective(trial, X, y):
    param_grid = {
        "n_estimators": trial.suggest_categorical("n_estimators", [5000]),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "num_leaves": trial.suggest_int("num_leaves", 20, 3000, step=20),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 200, 10000, step=100),
        "lambda_l1": trial.suggest_int("lambda_l1", 0, 100, step=5),
        "lambda_l2": trial.suggest_int("lambda_l2", 0, 100, step=5),
        "min_gain_to_split": trial.suggest_float("min_gain_to_split", 0, 15),
        "bagging_fraction": trial.suggest_float(
            "bagging_fraction", 0.2, 0.9, step=0.1
        ),
        "bagging_freq": trial.suggest_categorical("bagging_freq", [1]),
        "feature_fraction": trial.suggest_float(
            "feature_fraction", 0.2, 0.9, step=0.1
        ),
    }
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

    cv_scores = np.empty(5)

    for idx, (train_idx, test_idx) in enumerate(cv.split(X, y)):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        model = LGBMClassifier(objective="binary",
                               random_state=42,
                               silent=True,
                               n_jobs=8,
                               class_weight='balanced',
                               **param_grid
                              )

        model.fit(X_train, y_train,
                  eval_set=[(X_test, y_test)],
                  eval_metric="auc",
                  callbacks=[
                 LightGBMPruningCallback(trial, "auc")
            ],
                 )

        preds = model.predict_proba(X_test)
        cv_scores[idx] = roc_auc_score(y_test, preds[:, 1])

        return np.mean(cv_scores)

# %%
study = optuna.create_study(direction="maximize", study_name="lgbm")

study.optimize(lambda trial: objective(trial, train_x, train_y), n_trials=20)
# Out:
# [I 2022-01-25 00:14:16,317] A new study created in memory with name: lgbm
# [1]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [2]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [3]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [5]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [6]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [7]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [8]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [9]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [10]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [11]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [12]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [13]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [14]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [15]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [16]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [17]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [18]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [19]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [20]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
#
	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4798]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4799]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4800]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4801]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4802]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4803]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4804]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4805]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4806]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4807]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4808]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4809]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4810]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4811]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4812]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4813]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4814]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4815]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4816]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4817]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4818]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4819]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4820]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4821]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4822]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4823]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4824]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4825]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4826]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4827]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4828]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4829]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4830]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4831]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4832]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4833]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4834]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4835]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4836]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4837]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4838]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4839]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4840]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4841]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4842]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4843]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4844]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4845]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4846]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4847]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4848]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4849]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4850]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4851]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4852]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4853]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4854]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4855]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4856]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4857]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4858]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4859]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4860]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4861]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4862]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4863]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4864]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4865]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4866]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4867]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4868]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4869]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4870]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4871]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4872]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4873]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4874]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4875]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4876]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4877]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4878]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4879]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4880]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4881]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4882]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4883]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4884]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4885]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4886]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4887]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4888]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4889]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4890]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4891]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4892]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4893]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4894]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4895]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4896]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4897]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4898]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4899]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4900]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4901]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4902]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4903]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4904]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4905]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4906]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4907]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4908]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4909]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4910]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4911]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4912]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4913]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4914]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4915]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4916]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4917]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4918]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4919]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4920]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4921]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4922]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4923]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4924]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4925]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4926]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4927]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4928]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4929]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4930]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4931]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4932]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4933]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4934]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4935]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4936]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4937]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4938]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4939]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4940]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4941]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4942]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4943]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4944]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4945]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4946]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4947]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4948]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4949]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4950]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4951]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4952]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4953]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4954]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4955]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4956]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4957]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4958]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4959]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4960]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4961]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4962]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4963]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4964]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4965]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4966]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4967]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4968]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4969]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4970]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4971]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4972]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4973]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4974]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4975]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4976]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4977]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4978]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4979]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4980]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4981]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4982]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4983]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4984]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4985]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4986]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4987]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4988]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4989]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4990]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4991]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4992]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4993]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4994]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4995]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4996]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4997]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4998]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [4999]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [5000]	valid_0's auc: 0.5	valid_0's binary_logloss: 0.693147
# [I 2022-01-25 00:19:01,774] Trial 7 finished with value: 0.1 and parameters: {'n_estimators': 5000, 'learning_rate': 0.2625372929573469, 'num_leaves': 300, 'max_depth': 5, 'min_data_in_leaf': 10000, 'lambda_l1': 50, 'lambda_l2': 0, 'min_gain_to_split': 3.9112676184945987, 'bagging_fraction': 0.30000000000000004, 'bagging_freq': 1, 'feature_fraction': 0.6000000000000001}. Best is trial 4 with value: 0.19319561363342844.

# %%
clf = LGBMClassifier(objective="binary",
                               random_state=42,
                               silent=True,
                               n_jobs=8,
                               class_weight='balanced',
                               **study.best_params
                              )

clf.fit(X, y)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=55, reg_alpha=0.0 will be ignored. Current value: lambda_l1=55
# [LightGBM] [Warning] bagging_fraction is set=0.6000000000000001, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6000000000000001
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] min_data_in_leaf is set=800, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=800
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_gain_to_split is set=0.9026135572126254, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.9026135572126254
# [LightGBM] [Warning] lambda_l2 is set=40, reg_lambda=0.0 will be ignored. Current value: lambda_l2=40
# LGBMClassifier(bagging_fraction=0.6000000000000001, bagging_freq=1,
#                class_weight='balanced', feature_fraction=0.8, lambda_l1=55,
#                lambda_l2=40, learning_rate=0.2680163741968798, max_depth=9,
#                min_data_in_leaf=800, min_gain_to_split=0.9026135572126254,
#                n_estimators=5000, n_jobs=8, num_leaves=420, objective='binary',
#                random_state=42)

# %%
pred = clf.predict(sub)

# %%
sub['Predicted'] = pred
sub['Id'] = sub_id

# %%
sub[['Id', 'Predicted']].to_csv('rff.csv', index=False)

# %%
sub['Predicted'].value_counts()
# Out:
# 0.0    2494
# 1.0     813
# Name: Predicted, dtype: int64
